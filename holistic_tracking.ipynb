# %%
import cv2
import numpy as np
import mediapipe as mp

# %%
# %config Completer.use_jedi = False

# %%
mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic

# %%
cap = cv2.VideoCapture("video.mp4")

while cap.isOpened():
    ret, frame = cap.read()
    
    if ret:
        cv2.imshow("video", frame)
        
        k = cv2.waitKey(10)
        if k == ord('q'):
            break
    else:
        break
        
cap.release()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture("video.mp4")

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        
#         image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        image = frame.copy()
        results = holistic.process(image)
#         print(results)
        
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS)
        
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
        
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
        
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS)
    
        if ret:
            cv2.imshow("video", image)
        
            k = cv2.waitKey(1)
            if k == ord('q'):
                break
        else:
            break
        
cap.release()
cv2.destroyAllWindows()

# %%
results
# Out:
# mediapipe.python.solution_base.SolutionOutputs

# %%
mp_drawing.draw_detection??
# Out:
# Signature:
# mp_drawing.draw_detection(
#     image: numpy.ndarray,
#     detection: mediapipe.framework.formats.detection_pb2.Detection,
#     keypoint_drawing_spec: mediapipe.python.solutions.drawing_utils.DrawingSpec = DrawingSpec(color=(0, 0, 255), thickness=2, circle_radius=2),
#     bbox_drawing_spec: mediapipe.python.solutions.drawing_utils.DrawingSpec = DrawingSpec(color=(224, 224, 224), thickness=2, circle_radius=2),
# )
# Source:
# def draw_detection(
#     image: np.ndarray,
#     detection: detection_pb2.Detection,
#     keypoint_drawing_spec: DrawingSpec = DrawingSpec(color=RED_COLOR),
#     bbox_drawing_spec: DrawingSpec = DrawingSpec()):
#   """Draws the detction bounding box and keypoints on the image.
#
#   Args:
#     image: A three channel RGB image represented as numpy ndarray.
#     detection: A detection proto message to be annotated on the image.
#     keypoint_drawing_spec: A DrawingSpec object that specifies the keypoints'
# ...

# %%
cap = cv2.VideoCapture("video.mp4")

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        
#         image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        image = frame.copy()
        results = holistic.process(image)
#         print(results)
        
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, mp_drawing.DrawingSpec(color=(255,0,0), thickness=3, circle_radius=3), mp_drawing.DrawingSpec(color=(255,0,0), thickness=3, circle_radius=3))
        
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, mp_drawing.DrawingSpec(color=(0,255,0), thickness=3, circle_radius=3), mp_drawing.DrawingSpec(color=(0,255,0), thickness=3, circle_radius=3))
        
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, mp_drawing.DrawingSpec(color=(0,255,0), thickness=3, circle_radius=3), mp_drawing.DrawingSpec(color=(0,255,0), thickness=3, circle_radius=3))
        
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, mp_drawing.DrawingSpec(color=(255,255,0), thickness=3, circle_radius=3), mp_drawing.DrawingSpec(color=(255,0,255), thickness=3, circle_radius=3))
    
        if ret:
            cv2.imshow("video", image)
        
            k = cv2.waitKey(1)
            if k == ord('q'):
                break
        else:
            break
        
cap.release()
cv2.destroyAllWindows()

# %%
cv2.destroyAllWindows()

# %%
results
# Out:
# mediapipe.python.solution_base.SolutionOutputs

# %%
results.face_landmarks.landmark
# Out:
# [x: 0.4206526577472687
# y: 0.26290273666381836
# z: -0.009274505078792572
# , x: 0.43401262164115906
# y: 0.23955009877681732
# z: -0.02086668275296688
# , x: 0.42267727851867676
# y: 0.24612896144390106
# z: -0.010532419197261333
# , x: 0.42668551206588745
# y: 0.21456411480903625
# z: -0.020321061834692955
# , x: 0.43556901812553406
# y: 0.23214919865131378
# z: -0.022467363625764847
# , x: 0.4337794780731201
# y: 0.22228147089481354
# z: -0.021306321024894714
# , x: 0.4262304902076721
# y: 0.196660578250885
# z: -0.012402168475091457
# , x: 0.38016411662101746
# y: 0.1886620819568634
# z: -0.022499704733490944
# , x: 0.42561808228492737
# y: 0.1750006526708603
# z: -0.010376889258623123
# , x: 0.4273816645145416
# y: 0.16430500149726868
# z: -0.01150091178715229
# , x: 0.4268067181110382
# y: 0.12707799673080444
# z: -0.009761822409927845
# , x: 0.4195292592048645
# y: 0.26646679639816284
# z: -0.008545448072254658
# , x: 0.4177968502044678
# y: 0.2690645456314087
# ...

# %%
len(results.face_landmarks.landmark)
# Out:
# 468

# %%
results.pose_landmarks.landmark
# Out:
# [x: 0.4725099205970764
# y: 0.26983463764190674
# z: -0.346011221408844
# visibility: 0.9999669194221497
# , x: 0.4775473475456238
# y: 0.2505013644695282
# z: -0.3361979126930237
# visibility: 0.9999263882637024
# , x: 0.4809677004814148
# y: 0.24916192889213562
# z: -0.33624786138534546
# visibility: 0.9999352693557739
# , x: 0.48468202352523804
# y: 0.248052179813385
# z: -0.3363299071788788
# visibility: 0.9999402165412903
# , x: 0.46973124146461487
# y: 0.2532130479812622
# z: -0.32248082756996155
# visibility: 0.9999254941940308
# , x: 0.4672921597957611
# y: 0.2537195086479187
# z: -0.3225601613521576
# visibility: 0.9999145865440369
# , x: 0.46502217650413513
# y: 0.25422045588493347
# z: -0.3225998282432556
# visibility: 0.999903678894043
# , x: 0.4967358112335205
# y: 0.2514992952346802
# z: -0.23923738300800323
# visibility: 0.9999455809593201
# , x: 0.4682820439338684
# y: 0.2581542432308197
# z: -0.1741466522216797
# visibility: 0.9997339248657227
# ...

# %%
len(results.pose_landmarks.landmark)
# Out:
# 33

# %%
results.right_hand_landmarks.landmark
# Out:
# [x: 0.1255350112915039
# y: 0.7514971494674683
# z: -1.0232562885903462e-07
# , x: 0.16114577651023865
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-f7e5ba59b7ca> in <module>
#       2 for data_point in results.pose_landmarks.landmark:
#       3     keypoints.append({
# ----> 4                          x: data_point.x,
#       5                          y: data_point.y,
#       6                          })
#
# NameError: name 'x' is not defined

# %%
len(keypoints)
# Out:
# 33

# %%
type(keypoints)
# Out:
# list

# %%
keypoints[0]
# Out:
# {'X': 0.4725099205970764, 'Y': 0.26983463764190674}

# %%
target = [0,1,2,4,5,11,12,13,14,15,16,23,24,25,26,27,28]
print(len(target))
# Out:
# 17

# %%
target_keypoints = []
for i in target:
    target_keypoints.append(keypoints[i])

# %%
len(target_keypoints)
# Out:
# 17

# %%
target_keypoints
# Out:
# [{'X': 0.4725099205970764, 'Y': 0.26983463764190674},
#  {'X': 0.4775473475456238, 'Y': 0.2505013644695282},
#  {'X': 0.4809677004814148, 'Y': 0.24916192889213562},
#  {'X': 0.46973124146461487, 'Y': 0.2532130479812622},
#  {'X': 0.4672921597957611, 'Y': 0.2537195086479187},
#  {'X': 0.5329371690750122, 'Y': 0.3325381278991699},
#  {'X': 0.46189141273498535, 'Y': 0.34471192955970764},
#  {'X': 0.5370498299598694, 'Y': 0.4674299955368042},
#  {'X': 0.45055490732192993, 'Y': 0.4542364776134491},
#  {'X': 0.49017661809921265, 'Y': 0.4516012966632843},
#  {'X': 0.41293081641197205, 'Y': 0.48756808042526245},
#  {'X': 0.5376412272453308, 'Y': 0.5517420172691345},
#  {'X': 0.49539756774902344, 'Y': 0.5547448992729187},
#  {'X': 0.5377535223960876, 'Y': 0.7036632299423218},
#  {'X': 0.4380486011505127, 'Y': 0.6740731000900269},
#  {'X': 0.5691164135932922, 'Y': 0.8751847147941589},
#  {'X': 0.4581243097782135, 'Y': 0.8410598635673523}]

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)

# %%
for i in target_keypoints[0]:
    print(target_keypoints[0][i])
# Out:
# 0.4725099205970764
# 0.26983463764190674

# %%
ls = []
for i in range(len(target_keypoints)):
    for p in target_keypoints[i]:
        ls.append(target_keypoints[i][p])
#         pass
#         print(i)

# %%
ls
# Out:
# [0.4725099205970764,
#  0.26983463764190674,
#  0.4775473475456238,
#  0.2505013644695282,
#  0.4809677004814148,
#  0.24916192889213562,
#  0.46973124146461487,
#  0.2532130479812622,
#  0.4672921597957611,
#  0.2537195086479187,
#  0.5329371690750122,
#  0.3325381278991699,
#  0.46189141273498535,
#  0.34471192955970764,
#  0.5370498299598694,
#  0.4674299955368042,
#  0.45055490732192993,
#  0.4542364776134491,
#  0.49017661809921265,
#  0.4516012966632843,
#  0.41293081641197205,
#  0.48756808042526245,
#  0.5376412272453308,
#  0.5517420172691345,
#  0.49539756774902344,
#  0.5547448992729187,
#  0.5377535223960876,
#  0.7036632299423218,
#  0.4380486011505127,
#  0.6740731000900269,
#  0.5691164135932922,
#  0.8751847147941589,
#  0.4581243097782135,
#  0.8410598635673523]

# %%
len(ls)
# Out:
# 34
